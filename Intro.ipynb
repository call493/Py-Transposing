# %% [markdown]
# <a href="https://colab.research.google.com/github/call493/Py-Transposing/blob/main/Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# GPU

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.4.1+cu121
# True

# %% [markdown]
# Automatic differentiation

# %%
import torch

#Creating a tensor with gradients
x = torch.tensor(2.0, requires_grad=True)
y = x**64 + 2*x**2 + x + 10
y.backward()
# print(x.grad)
print(x)
# Out:
# tensor(2., requires_grad=True)

# %%
pip install numpy torch

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
array, tensor = np.array([1,8,6]), torch.tensor([1,8,6])
print (array, tensor)
# Out:
# [1 8 6] tensor([1, 8, 6])

# %%
array, tensor = np.array([[4,5,7], [6,9,5], [4,5,6]]), torch.tensor([[4,5,7], [6,9,5], [4,5,6]])
print(array, tensor)
plt.imshow(tensor)
# Out:
# [[4 5 7]
#  [6 9 5]
#  [4 5 6]] tensor([[4, 5, 7],
#         [6, 9, 5],
#         [4, 5, 6]])

# %%
array, tensor = np.zeros((80,40,3)), torch.tensor(((80,40,3)))
plt.imshow(array)

# %%
array[:20,:20,:] = 255
plt.imshow(array)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
array[::3,::3,:] = 255
plt.imshow(array[:,:,0].T)

# %%
img = plt.imread('/content/dan-meyers-IQVFVH0ajag-unsplash.jpg')
plt.imshow(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img1 = img.copy()

# %%
img1[:2000,:1000,:] = 255
plt.imshow(img1)

# %%
img1.max()
# Out:
# 255

# %%
img.min()
# Out:
# 0

# %%
img.dtype
# Out:
# dtype('uint8')
